# %% [markdown]
# # Browser Intent Training (Colab)\n
# \n
# 1. Upload `training_data.csv` (columns: `message`, `label`).\n
# 2. Fine-tune DistilBERT.\n
# 3. Export ONNX for local CPU inference.

# %%
# !pip -q install transformers datasets optimum[onnxruntime] onnxruntime\n
print('Dependencies installed')

# %%
from pathlib import Path\n
import pandas as pd\n
\n
csv_path = Path('/content/training_data.csv')\n
if not csv_path.exists():\n
    raise FileNotFoundError('Upload training_data.csv to /content first.')\n
df = pd.read_csv(csv_path)\n
print(df.head())\n
print('rows:', len(df))

# %% [markdown]
# Add your fine-tuning and ONNX export code here.\n
# This scaffold intentionally stays lightweight for fast bootstrapping.
